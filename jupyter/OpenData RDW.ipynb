# %%
import pandas as pd
url = "https://opendata.rdw.nl/resource/m9d7-ebf2.json"
df = pd.io.json.read_json(url)
df.head()
# Out:
#   kenteken voertuigsoort  ... vervaldatum_tachograaf aantal_staanplaatsen
# 0   1ZSX86  Personenauto  ...                    NaN                  NaN
# 1   TRNS78  Personenauto  ...                    NaN                  NaN
# 2   11NPP3  Personenauto  ...                    NaN                  NaN
# 3   12JBHX  Personenauto  ...                    NaN                  NaN
# 4   TD140B  Personenauto  ...                    NaN                  NaN
#
# [5 rows x 66 columns]

# %%
df.describe()
# Out:
#        vervaldatum_apk  ...  aantal_staanplaatsen
# count     7.500000e+02  ...                   1.0
# mean      2.022041e+07  ...                  11.0
# std       2.293506e+04  ...                   NaN
# min       1.991051e+07  ...                  11.0
# 25%       2.022022e+07  ...                  11.0
# 50%       2.022062e+07  ...                  11.0
# 75%       2.022101e+07  ...                  11.0
# max       2.025093e+07  ...                  11.0
#
# [8 rows x 36 columns]

# %%
df
# Out:
#     kenteken voertuigsoort  ... vervaldatum_tachograaf aantal_staanplaatsen
# 0     1ZSX86  Personenauto  ...                    NaN                  NaN
# 1     TRNS78  Personenauto  ...                    NaN                  NaN
# 2     11NPP3  Personenauto  ...                    NaN                  NaN
# 3     12JBHX  Personenauto  ...                    NaN                  NaN
# 4     TD140B  Personenauto  ...                    NaN                  NaN
# ..       ...           ...  ...                    ...                  ...
# 995   TF199B  Personenauto  ...                    NaN                  NaN
# 996   H410HF  Personenauto  ...                    NaN                  NaN
# 997   97PTD5  Personenauto  ...                    NaN                  NaN
# 998   D896JL     Bromfiets  ...                    NaN                  NaN
# 999   PK94NL  Personenauto  ...                    NaN                  NaN
#
# [1000 rows x 66 columns]
