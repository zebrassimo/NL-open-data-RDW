# %%
import pandas as pd
url = "https://opendata.rdw.nl/resource/m9d7-ebf2.json?$limit=50000"
df = pd.io.json.read_json(url)
df.head()
# Out:
#   kenteken voertuigsoort  ... aantal_staanplaatsen afwijkende_maximum_snelheid
# 0   MHBF51    Motorfiets  ...                  NaN                         NaN
# 1   15KRL2  Personenauto  ...                  NaN                         NaN
# 2   30JNBP  Personenauto  ...                  NaN                         NaN
# 3   45ZKXB  Personenauto  ...                  NaN                         NaN
# 4   60GVL7  Personenauto  ...                  NaN                         NaN
#
# [5 rows x 67 columns]

# %%
df.describe()
# Out:
#        datum_tenaamstelling  ...  afwijkende_maximum_snelheid
# count          5.000000e+04  ...                          2.0
# mean           2.016670e+07  ...                        100.0
# std            5.232825e+04  ...                          0.0
# min            1.962073e+07  ...                        100.0
# 25%            2.015061e+07  ...                        100.0
# 50%            2.018112e+07  ...                        100.0
# 75%            2.020091e+07  ...                        100.0
# max            2.021103e+07  ...                        100.0
#
# [8 rows x 37 columns]
